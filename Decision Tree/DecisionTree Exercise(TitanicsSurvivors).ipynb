# %%
import pandas as pd

# %%
df=pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
abc=df.drop(['PassengerId','Name','SibSp', 'Parch','Ticket','Cabin','Embarked'], axis='columns')

# %%
len(abc)
# Out:
# 891

# %%
new_abc=abc.dropna()

# %%
len(abc)
# Out:
# 891

# %%
abc
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
len(abc)
# Out:
# 891

# %%
len(new_abc)
# Out:
# 714

# %%
new_abc
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 885         0       3  female  39.0  29.1250
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [714 rows x 5 columns]

# %%
target=new_abc['Survived']
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 714, dtype: int64

# %%
new_abc=new_abc.drop('Survived', axis='columns')
new_abc
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 885       3  female  39.0  29.1250
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [714 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le_sex= LabelEncoder()

# %%
new_abc['sex_n']= le_sex.fit_transform(new_abc['Sex'])

# %%
new_abc
# Out:
#      Pclass     Sex   Age     Fare  sex_n
# 0         3    male  22.0   7.2500      1
# 1         1  female  38.0  71.2833      0
# 2         3  female  26.0   7.9250      0
# 3         1  female  35.0  53.1000      0
# 4         3    male  35.0   8.0500      1
# ..      ...     ...   ...      ...    ...
# 885       3  female  39.0  29.1250      0
# 886       2    male  27.0  13.0000      1
# 887       1  female  19.0  30.0000      0
# 889       1    male  26.0  30.0000      1
# 890       3    male  32.0   7.7500      1
#
# [714 rows x 5 columns]

# %%
new_abc=new_abc.drop('Sex',axis='columns')

# %%
new_abc
# Out:
#      Pclass   Age     Fare  sex_n
# 0         3  22.0   7.2500      1
# 1         1  38.0  71.2833      0
# 2         3  26.0   7.9250      0
# 3         1  35.0  53.1000      0
# 4         3  35.0   8.0500      1
# ..      ...   ...      ...    ...
# 885       3  39.0  29.1250      0
# 886       2  27.0  13.0000      1
# 887       1  19.0  30.0000      0
# 889       1  26.0  30.0000      1
# 890       3  32.0   7.7500      1
#
# [714 rows x 4 columns]

# %%
new_abc
# Out:
#      Pclass   Age     Fare  sex_n
# 0         3  22.0   7.2500      1
# 1         1  38.0  71.2833      0
# 2         3  26.0   7.9250      0
# 3         1  35.0  53.1000      0
# 4         3  35.0   8.0500      1
# ..      ...   ...      ...    ...
# 885       3  39.0  29.1250      0
# 886       2  27.0  13.0000      1
# 887       1  19.0  30.0000      0
# 889       1  26.0  30.0000      1
# 890       3  32.0   7.7500      1
#
# [714 rows x 4 columns]

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 714, dtype: int64

# %%
from sklearn import tree

# %%
model=tree.DecisionTreeClassifier()

# %%
model.fit(new_abc,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(new_abc,target)
# Out:
# 0.9845938375350141

# %%
new_abc
# Out:
#      Pclass   Age     Fare  sex_n
# 0         3  22.0   7.2500      1
# 1         1  38.0  71.2833      0
# 2         3  26.0   7.9250      0
# 3         1  35.0  53.1000      0
# 4         3  35.0   8.0500      1
# ..      ...   ...      ...    ...
# 885       3  39.0  29.1250      0
# 886       2  27.0  13.0000      1
# 887       1  19.0  30.0000      0
# 889       1  26.0  30.0000      1
# 890       3  32.0   7.7500      1
#
# [714 rows x 4 columns]

# %%
model.predict([[3,22,7.2500,1]])
# Out:
# array([0])
